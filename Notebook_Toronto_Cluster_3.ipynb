# %% [markdown]
# # Agrupación y Segmentación de Vecindarios en la Ciudad de Toronto, Canadá

# %% [markdown]
# Importación de las librerias

# %%
print("Inicio de importación")
import pandas as pd
import requests
from bs4 import BeautifulSoup
import numpy as np
from geopy.geocoders import Nominatim
from sklearn.cluster import KMeans
import folium
import matplotlib.cm as cm
import matplotlib.colors as colors
print("Importación Exitosa")
# Out:
# Inicio de importación
# Importación Exitosa

# %% [markdown]
# ## Primer parte

# %% [markdown]
# Creación de la tabla tomando los datos de Tornto desde Wikipedia

# %%
from IPython.display import IFrame
url = "https://en.wikipedia.org/w/index.php?title=List_of_postal_codes_of_Canada:_M&oldid=958425468"

# %% [markdown]
# Uso de Pandas para procesar los datos y crear la tabla

# %%
wiki_html = requests.get(url).text
soup = BeautifulSoup(wiki_html, 'html.parser')
data = []
for tr in soup.tbody.find_all('tr'):
    data.append([td.get_text().strip() for td in tr.find_all('td')])
dataFrame = pd.DataFrame(data,columns=['CodigoPostal','Ciudad','Barrio'])
dataFrame.head(12)
# Out:
#    CodigoPostal            Ciudad                                       Barrio
# 0          None              None                                         None
# 1           M1A      Not assigned
# 2           M2A      Not assigned
# 3           M3A        North York                                    Parkwoods
# 4           M4A        North York                             Victoria Village
# 5           M5A  Downtown Toronto                    Regent Park, Harbourfront
# 6           M6A        North York             Lawrence Manor, Lawrence Heights
# 7           M7A  Downtown Toronto  Queen's Park, Ontario Provincial Government
# 8           M8A      Not assigned
# 9           M9A         Etobicoke                             Islington Avenue
# 10          M1B       Scarborough                               Malvern, Rouge
# 11          M2B      Not assigned

# %% [markdown]
# Borramos la primera linea vacía y limpiamos las ciudades no asignadas

# %%
df = dataFrame.dropna()
df['Ciudad'].replace('Not assigned',np.nan,inplace=True)
df.dropna(subset=['Ciudad'],inplace=True)
df.head(12)
# Out:
# /var/folders/79/4l20n_4n3dn2twlpxr55cbg80000gn/T/ipykernel_94031/1451773692.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Ciudad'].replace('Not assigned',np.nan,inplace=True)
# /var/folders/79/4l20n_4n3dn2twlpxr55cbg80000gn/T/ipykernel_94031/1451773692.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.dropna(subset=['Ciudad'],inplace=True)
#    CodigoPostal            Ciudad  \
# 3           M3A        North York
# 4           M4A        North York
# 5           M5A  Downtown Toronto
# 6           M6A        North York
# 7           M7A  Downtown Toronto
# 9           M9A         Etobicoke
# 10          M1B       Scarborough
# 12          M3B        North York
# 13          M4B         East York
# 14          M5B  Downtown Toronto
# 15          M6B        North York
# 18          M9B         Etobicoke
#
#                                                Barrio
# 3                                           Parkwoods
# 4                                    Victoria Village
# 5                           Regent Park, Harbourfront
# 6                    Lawrence Manor, Lawrence Heights
# 7         Queen's Park, Ontario Provincial Government
# 9                                    Islington Avenue
# 10                                     Malvern, Rouge
# 12                                          Don Mills
# 13                    Parkview Hill, Woodbine Gardens
# 14                           Garden District, Ryerson
# 15                                          Glencairn
# 18  West Deane Park, Princess Gardens, Martin Grov...

# %% [markdown]
# Agrego el nombre de la ciudad al barrio si el barrio no esta asignado pero tiene ciudad

# %%
for index, row in df.iterrows():
    if row["Barrio"] == "Not assigned":
        row["Barrio"] = row["Ciudad"]
df.head()
# Out:
#   CodigoPostal            Ciudad                                       Barrio
# 3          M3A        North York                                    Parkwoods
# 4          M4A        North York                             Victoria Village
# 5          M5A  Downtown Toronto                    Regent Park, Harbourfront
# 6          M6A        North York             Lawrence Manor, Lawrence Heights
# 7          M7A  Downtown Toronto  Queen's Park, Ontario Provincial Government

# %% [markdown]
# Agrupo el conjunto de datos por codigo postal y ciudad

# %%
df = df.groupby(['CodigoPostal', 'Ciudad',])['Barrio'].apply(', '.join).reset_index()
df.columns = ['Codigo Postal', 'Ciudad', 'Barrio']
df.head(50)
# Out:
#    Codigo Postal           Ciudad  \
# 0            M1B      Scarborough
# 1            M1C      Scarborough
# 2            M1E      Scarborough
# 3            M1G      Scarborough
# 4            M1H      Scarborough
# 5            M1J      Scarborough
# 6            M1K      Scarborough
# 7            M1L      Scarborough
# 8            M1M      Scarborough
# 9            M1N      Scarborough
# 10           M1P      Scarborough
# 11           M1R      Scarborough
# 12           M1S      Scarborough
# 13           M1T      Scarborough
# 14           M1V      Scarborough
# 15           M1W      Scarborough
# 16           M1X      Scarborough
# 17           M2H       North York
# 18           M2J       North York
# 19           M2K       North York
# 20           M2L       North York
# 21           M2M       North York
# 22           M2N       North York
# 23           M2P       North York
# 24           M2R       North York
# 25           M3A       North York
# 26           M3B       North York
# 27           M3C       North York
# 28           M3H       North York
# 29           M3J       North York
# 30           M3K       North York
# 31           M3L       North York
# 32           M3M       North York
# 33           M3N       North York
# 34           M4A       North York
# 35           M4B        East York
# 36           M4C        East York
# 37           M4E     East Toronto
# 38           M4G        East York
# 39           M4H        East York
# 40           M4J        East York
# 41           M4K     East Toronto
# 42           M4L     East Toronto
# 43           M4M     East Toronto
# 44           M4N  Central Toronto
# 45           M4P  Central Toronto
# 46           M4R  Central Toronto
# 47           M4S  Central Toronto
# 48           M4T  Central Toronto
# 49           M4V  Central Toronto
#
#                                                Barrio
# 0                                      Malvern, Rouge
# 1              Rouge Hill, Port Union, Highland Creek
# 2                   Guildwood, Morningside, West Hill
# 3                                              Woburn
# 4                                           Cedarbrae
# 5                                 Scarborough Village
# 6         Kennedy Park, Ionview, East Birchmount Park
# 7                     Golden Mile, Clairlea, Oakridge
# 8     Cliffside, Cliffcrest, Scarborough Village West
# 9                         Birch Cliff, Cliffside West
# 10  Dorset Park, Wexford Heights, Scarborough Town...
# 11                                  Wexford, Maryvale
# 12                                          Agincourt
# 13            Clarks Corners, Tam O'Shanter, Sullivan
# 14  Milliken, Agincourt North, Steeles East, L'Amo...
# 15                      Steeles West, L'Amoreaux West
# 16                                        Upper Rouge
# 17                                  Hillcrest Village
# 18                       Fairview, Henry Farm, Oriole
# 19                                    Bayview Village
# 20                           York Mills, Silver Hills
# 21                            Willowdale, Newtonbrook
# 22                                         Willowdale
# 23                                    York Mills West
# 24                                         Willowdale
# 25                                          Parkwoods
# 26                                          Don Mills
# 27                                          Don Mills
# 28    Bathurst Manor, Wilson Heights, Downsview North
# 29                    Northwood Park, York University
# 30                                          Downsview
# 31                                          Downsview
# 32                                          Downsview
# 33                                          Downsview
# 34                                   Victoria Village
# 35                    Parkview Hill, Woodbine Gardens
# 36                                   Woodbine Heights
# 37                                        The Beaches
# 38                                            Leaside
# 39                                   Thorncliffe Park
# 40                                       East Toronto
# 41                       The Danforth West, Riverdale
# 42                     India Bazaar, The Beaches West
# 43                                    Studio District
# 44                                      Lawrence Park
# 45                                   Davisville North
# 46                 North Toronto West,  Lawrence Park
# 47                                         Davisville
# 48                        Moore Park, Summerhill East
# 49  Summerhill West, Rathnelly, South Hill, Forest...

# %%
df.shape
# Out:
# (103, 3)

# %% [markdown]
# ## Segunda parte

# %% [markdown]
# Para obtener los resultados de las coordenadas utilizaremos el archivo .csv

# %%
geospatial_data = pd.read_csv('https://cocl.us/Geospatial_data')

# %% [markdown]
# Verificamos que el tamaño de la colección de datos obtenidos es igual al del conjunto procesado anterior

# %%
geospatial_data.head()
# Out:
#   Postal Code   Latitude  Longitude
# 0         M1B  43.806686 -79.194353
# 1         M1C  43.784535 -79.160497
# 2         M1E  43.763573 -79.188711
# 3         M1G  43.770992 -79.216917
# 4         M1H  43.773136 -79.239476

# %%
print("Conjunto de datos procesado anterior",df.shape)
print("Geopatial data ", geospatial_data.shape)
# Out:
# Conjunto de datos procesado anterior (103, 3)
# Geopatial data  (103, 3)

# %% [markdown]
# Coinciden ambas por lo tanto se procesó la misma cantidad

# %% [markdown]
# Agregaremos la información de las coordenadas al conjunto de datos de codigos postales

# %%
#combinaremos las columnas utilizando un join por la clave codigo postal
df = pd.concat(
    [df.set_index('Codigo Postal'), geospatial_data.set_index('Postal Code')],
    axis=1, join='inner')
df.head()
# Out:
#           Ciudad                                  Barrio   Latitude  Longitude
# M1B  Scarborough                          Malvern, Rouge  43.806686 -79.194353
# M1C  Scarborough  Rouge Hill, Port Union, Highland Creek  43.784535 -79.160497
# M1E  Scarborough       Guildwood, Morningside, West Hill  43.763573 -79.188711
# M1G  Scarborough                                  Woburn  43.770992 -79.216917
# M1H  Scarborough                               Cedarbrae  43.773136 -79.239476

# %% [markdown]
# Se perdió el nombre de la columna Codigo Postal ya que se utilizo como clave, por lo que corregimos agregando nuevamente el nombre de la columna

# %%
df.reset_index(inplace=True)
df.head()
df.rename(columns={'index': 'Codigo_Postal'}, inplace=True)
df.head(12)
# Out:
#    Codigo_Postal       Ciudad  \
# 0            M1B  Scarborough
# 1            M1C  Scarborough
# 2            M1E  Scarborough
# 3            M1G  Scarborough
# 4            M1H  Scarborough
# 5            M1J  Scarborough
# 6            M1K  Scarborough
# 7            M1L  Scarborough
# 8            M1M  Scarborough
# 9            M1N  Scarborough
# 10           M1P  Scarborough
# 11           M1R  Scarborough
#
#                                                Barrio   Latitude  Longitude
# 0                                      Malvern, Rouge  43.806686 -79.194353
# 1              Rouge Hill, Port Union, Highland Creek  43.784535 -79.160497
# 2                   Guildwood, Morningside, West Hill  43.763573 -79.188711
# 3                                              Woburn  43.770992 -79.216917
# 4                                           Cedarbrae  43.773136 -79.239476
# 5                                 Scarborough Village  43.744734 -79.239476
# 6         Kennedy Park, Ionview, East Birchmount Park  43.727929 -79.262029
# 7                     Golden Mile, Clairlea, Oakridge  43.711112 -79.284577
# 8     Cliffside, Cliffcrest, Scarborough Village West  43.716316 -79.239476
# 9                         Birch Cliff, Cliffside West  43.692657 -79.264848
# 10  Dorset Park, Wexford Heights, Scarborough Town...  43.757410 -79.273304
# 11                                  Wexford, Maryvale  43.750071 -79.295849

# %% [markdown]
# ## Parte 3

# %% [markdown]
# Se obtiene los datos de longitud y latitud utilizando geopy

# %%
ciudad = 'Toronto, Canada'
geolocator = Nominatim(user_agent="toronto_explorer")
coordenadas = geolocator.geocode(ciudad)
print('Coordenadas de Toronto: {}, {}.'.format(
    coordenadas.latitude, coordenadas.longitude))
# Out:
# Coordenadas de Toronto: 43.6534817, -79.3839347.

# %% [markdown]
# Mapa de toronto utilizando Folium

# %%
mapa_toronto = folium.Map(
    location=[coordenadas.latitude, coordenadas.longitude],
    zoom_start=10)
mapa_toronto
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f9f237af2048f798102d5f3a1edce617 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f9f237af2048f798102d5f3a1edce617&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f9f237af2048f798102d5f3a1edce617 = L.map(
#                 &quot;map_f9f237af2048f798102d5f3a1edce617&quot;,
#                 {
#                     center: [43.6534817, -79.3839347],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ded8032fa2f262a797f0d24ca57add6d = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_f9f237af2048f798102d5f3a1edce617);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Se agrega la información procesada de barrios y ciudad al mapa

# %%
for _, row in df.iterrows():
    label = '{} ({}), {}'.format(
        row.Codigo_Postal, row.Barrio, row.Ciudad)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [row.Latitude, row.Longitude],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(mapa_toronto) 
    
mapa_toronto
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f9f237af2048f798102d5f3a1edce617 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f9f237af2048f798102d5f3a1edce617&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f9f237af2048f798102d5f3a1edce617 = L.map(
#                 &quot;map_f9f237af2048f798102d5f3a1edce617&quot;,
#                 {
#                     center: [43.6534817, -79.3839347],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ded8032fa2f262a797f0d24ca57add6d = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_f9f237af2048f798102d5f3a1edce617);
#
#
#             var circle_marker_6ba5dffbe90f0c77e129a73ad8c7e6d6 = L.circleMarker(
#                 [43.8066863, -79.1943534],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3186cc&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_f9f237af2048f798102d5f3a1edce617);
#
#
#         var popup_03f78c63af8efe295d3f9bb48b350ce6 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_939eef492d7ffc12a758cd5011d97d9b = $(`&lt;div id=&quot;html_939eef492d7ffc12a758cd5011d97d9b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;M1B (Malvern, Rouge), Scarborough&lt;/div&gt;`)[0];
#                 popup_03f78c63af8efe295d3f9bb48b350ce6.setContent(html_939eef492d7ffc12a758cd5011d97d9b);
#
#
#
#         circle_marker_6ba5dffbe90f0c77e129a73ad8c7e6d6.bindPopup(popup_03f78c63af8efe295d3f9bb48b350ce6)
#         ;
#
#
#
#
#             var circle_marker_b6957ddd3e90909e3f2fc3d5921598a1 = L.circleMarker(
#                 [43.7845351, -79.1604971],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3186cc&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_f9f237af2048f798102d5f3a1edce617);
#
#
#         var popup_0eb8c760fc2350e6da1b70cd38b8fc15 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_fe5982d10e0e3c7bbe32050fd17efec4 = $(`&lt;div id=&quot;html_fe5982d10e0e3c7bbe32050fd17efec4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;M1C (Rouge Hill, Port Union, Highland Creek), Scarborough&lt;/div&gt;`)[0];
#                 popup_0eb8c760fc2350e6da1b70cd38b8fc15.setContent(html_fe5982d10e0e3c7bbe32050fd17efec4);
#
#
#
#         circle_marker_b6957ddd3e90909e3f2fc3d5921598a1.bindPopup(popup_0eb8c760fc2350e6da1b70cd38b8fc15)
#         ;
#
#
#
#
#             var circle_marker_b992f0af8deb279c9aed020e24b15278 = L.circleMarker(
#                 [43.7635726, -79.1887115],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3186cc&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_f9f237af2048f798102d5f3a1edce617);
#
#
#         var popup_ff66362ce89bd99cfb296607356abbb1 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_fcfdeb5d3927955da3774147b470a14f = $(`&lt;div id=&quot;html_fcfdeb5d3927955da3774147b470a14f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;M1E (Guildwood, Morningside, West Hill), Scarborough&lt;/div&gt;`)[0];
#                 popup_ff66362ce89bd99cfb296607356abbb1.setContent(html_fcfdeb5d3927955da3774147b470a14f);
#
#
#
#         circle_marker_b992f0af8deb279c9aed020e24b15278.bindPopup(popup_ff66362ce89bd99cfb296607356abbb1)
#         ;
#
#
#
#
#             var circle_marker_16728beede8a890cab30bac62ba51ff8 = L.circleMarker(
#                 [43.7709921, -79.2169174],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: tr

# %% [markdown]
# Se va a filtrar solamente por los barrios de la ciudad de Toronto

# %%
# Nuevo data frame solamente con la ciudad de Toronto
toronto_data = df[df.Ciudad.str.contains('Toronto')]
toronto_data.reset_index(inplace=True, drop=True)
toronto_data
# Out:
#    Codigo_Postal            Ciudad  \
# 0            M4E      East Toronto
# 1            M4K      East Toronto
# 2            M4L      East Toronto
# 3            M4M      East Toronto
# 4            M4N   Central Toronto
# 5            M4P   Central Toronto
# 6            M4R   Central Toronto
# 7            M4S   Central Toronto
# 8            M4T   Central Toronto
# 9            M4V   Central Toronto
# 10           M4W  Downtown Toronto
# 11           M4X  Downtown Toronto
# 12           M4Y  Downtown Toronto
# 13           M5A  Downtown Toronto
# 14           M5B  Downtown Toronto
# 15           M5C  Downtown Toronto
# 16           M5E  Downtown Toronto
# 17           M5G  Downtown Toronto
# 18           M5H  Downtown Toronto
# 19           M5J  Downtown Toronto
# 20           M5K  Downtown Toronto
# 21           M5L  Downtown Toronto
# 22           M5N   Central Toronto
# 23           M5P   Central Toronto
# 24           M5R   Central Toronto
# 25           M5S  Downtown Toronto
# 26           M5T  Downtown Toronto
# 27           M5V  Downtown Toronto
# 28           M5W  Downtown Toronto
# 29           M5X  Downtown Toronto
# 30           M6G  Downtown Toronto
# 31           M6H      West Toronto
# 32           M6J      West Toronto
# 33           M6K      West Toronto
# 34           M6P      West Toronto
# 35           M6R      West Toronto
# 36           M6S      West Toronto
# 37           M7A  Downtown Toronto
# 38           M7Y      East Toronto
#
#                                                Barrio   Latitude  Longitude
# 0                                         The Beaches  43.676357 -79.293031
# 1                        The Danforth West, Riverdale  43.679557 -79.352188
# 2                      India Bazaar, The Beaches West  43.668999 -79.315572
# 3                                     Studio District  43.659526 -79.340923
# 4                                       Lawrence Park  43.728020 -79.388790
# 5                                    Davisville North  43.712751 -79.390197
# 6                  North Toronto West,  Lawrence Park  43.715383 -79.405678
# 7                                          Davisville  43.704324 -79.388790
# 8                         Moore Park, Summerhill East  43.689574 -79.383160
# 9   Summerhill West, Rathnelly, South Hill, Forest...  43.686412 -79.400049
# 10                                           Rosedale  43.679563 -79.377529
# 11                        St. James Town, Cabbagetown  43.667967 -79.367675
# 12                               Church and Wellesley  43.665860 -79.383160
# 13                          Regent Park, Harbourfront  43.654260 -79.360636
# 14                           Garden District, Ryerson  43.657162 -79.378937
# 15                                     St. James Town  43.651494 -79.375418
# 16                                        Berczy Park  43.644771 -79.373306
# 17                                 Central Bay Street  43.657952 -79.387383
# 18                           Richmond, Adelaide, King  43.650571 -79.384568
# 19  Harbourfront East, Union Station, Toronto Islands  43.640816 -79.381752
# 20           Toronto Dominion Centre, Design Exchange  43.647177 -79.381576
# 21                     Commerce Court, Victoria Hotel  43.648198 -79.379817
# 22                                           Roselawn  43.711695 -79.416936
# 23                           Forest Hill North & West  43.696948 -79.411307
# 24                The Annex, North Midtown, Yorkville  43.672710 -79.405678
# 25                     University of Toronto, Harbord  43.662696 -79.400049
# 26          Kensington Market, Chinatown, Grange Park  43.653206 -79.400049
# 27  CN Tower, King and Spadina, Railway Lands, Har...  43.628947 -79.394420
# 28                                     Stn A PO Boxes  43.646435 -79.374846
# 29             First Canadian Place, Underground city  43.648429 -79.382280
# 30                                           Christie  43.669542 -79.422564
# 31                       Dufferin, Dovercourt Village  43.669005 -79.442259
# 32                           Little Portugal, Trinity  43.647927 -79.419750
# 33       Brockton, Parkdale Village, Exhibition Place  43.636847 -79.428191
# 34                      High Park, The Junction South  43.661608 -79.464763
# 35                             Parkdale, Roncesvalles  43.648960 -79.456325
# 36                                 Runnymede, Swansea  43.651571 -79.484450
# 37        Queen's Park, Ontario Provincial Government  43.662301 -79.389494
# 38  Business reply mail Processing Centre, South C...  43.662744 -79.321558

# %%
toronto_data.shape
# Out:
# (39, 5)

# %% [markdown]
# Visualizamos los datos de toronto en el mapa

# %%
mapa_toronto = folium.Map(
    location=[coordenadas.latitude, coordenadas.longitude],
    zoom_start=11)

for _, row in toronto_data.iterrows():
    label = '{} ({}), {}'.format(
        row.Codigo_Postal, row.Barrio, row.Ciudad)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [row.Latitude, row.Longitude],
        radius=5,
        popup=label,
        color='red',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(mapa_toronto) 
    
mapa_toronto
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8889692ac4ff45745cbf719f40168dc7 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8889692ac4ff45745cbf719f40168dc7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8889692ac4ff45745cbf719f40168dc7 = L.map(
#                 &quot;map_8889692ac4ff45745cbf719f40168dc7&quot;,
#                 {
#                     center: [43.6534817, -79.3839347],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_04330425caf321b66cb86023361fb01e = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_8889692ac4ff45745cbf719f40168dc7);
#
#
#             var circle_marker_efc2657c11fef63603659c4285f77909 = L.circleMarker(
#                 [43.6763574, -79.2930312],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3186cc&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_8889692ac4ff45745cbf719f40168dc7);
#
#
#         var popup_2f880866b51320d77d0125e38e214ea6 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ba2dcd7fc9db077e377734eb775b83b7 = $(`&lt;div id=&quot;html_ba2dcd7fc9db077e377734eb775b83b7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;M4E (The Beaches), East Toronto&lt;/div&gt;`)[0];
#                 popup_2f880866b51320d77d0125e38e214ea6.setContent(html_ba2dcd7fc9db077e377734eb775b83b7);
#
#
#
#         circle_marker_efc2657c11fef63603659c4285f77909.bindPopup(popup_2f880866b51320d77d0125e38e214ea6)
#         ;
#
#
#
#
#             var circle_marker_85efda1780ff2ef6cfadb95ccaea29d9 = L.circleMarker(
#                 [43.6795571, -79.352188],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3186cc&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_8889692ac4ff45745cbf719f40168dc7);
#
#
#         var popup_af1f8aa21db56134c5d6a98ea9cd5e07 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a22749efa763658ee72026d58c984702 = $(`&lt;div id=&quot;html_a22749efa763658ee72026d58c984702&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;M4K (The Danforth West, Riverdale), East Toronto&lt;/div&gt;`)[0];
#                 popup_af1f8aa21db56134c5d6a98ea9cd5e07.setContent(html_a22749efa763658ee72026d58c984702);
#
#
#
#         circle_marker_85efda1780ff2ef6cfadb95ccaea29d9.bindPopup(popup_af1f8aa21db56134c5d6a98ea9cd5e07)
#         ;
#
#
#
#
#             var circle_marker_c50013abef55ea7469552bf1513344d8 = L.circleMarker(
#                 [43.6689985, -79.3155716],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3186cc&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_8889692ac4ff45745cbf719f40168dc7);
#
#
#         var popup_c9c311cbb1be2bb4bce08169d242f0ee = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ad8c46e9b95d8c95def838f1776f2cb2 = $(`&lt;div id=&quot;html_ad8c46e9b95d8c95def838f1776f2cb2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;M4L (India Bazaar, The Beaches West), East Toronto&lt;/div&gt;`)[0];
#                 popup_c9c311cbb1be2bb4bce08169d242f0ee.setContent(html_ad8c46e9b95d8c95def838f1776f2cb2);
#
#
#
#         circle_marker_c50013abef55ea7469552bf1513344d8.bindPopup(popup_c9c311cbb1be2bb4bce08169d242f0ee)
#         ;
#
#
#
#
#             var circle_marker_0c49b71637f1567f91c2a04b4f185bcd = L.circleMarker(
#                 [43.6595255, -79.340923],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor

# %% [markdown]
# Se van a explorar los barrios de nuestro data frame, obteniendo primero las coordenadas geográficas de un barrio y a partir de esto obtenemos los venues de esta locación

# %%
venues_list = list()

for name, lat, lng in zip(toronto_data['Barrio'], toronto_data['Latitude'], toronto_data['Longitude']):
    print("Procesando los venues de Toronto:", name)
    
    # API request URL
    limit = 50
    radius = 500
    explore_url_prefix = 'https://api.foursquare.com/v3/places/search'
    
    url = '{}?ll={}%2C{}&limit={}'.format(
        explore_url_prefix, 
        lat, lng, limit)
    
    headers = {
    "accept": "application/json",
    "Authorization": "fsq3QU7ZPPlgHjAHxcrxXMqjXTt7QlulQ320poEiVv/qGD0="
    }

    # Request
    neighborhood_venues = requests.get(url,headers=headers).json()["results"]
    no_category = 'No Category'
    # Agregar la informacion relevante a la lista, en caso de no tener categoria se marca como sin categoria
    for v in neighborhood_venues:
        if len(v['categories']):
            venues_list.append((
            name, lat, lng,
            v['name'], 
            v['geocodes']['main']['latitude'], 
            v['geocodes']['main']['longitude'],  
            v['categories'][0]['name']))
        else:
            venues_list.append((
            name, lat, lng,
            v['name'], 
            v['geocodes']['main']['latitude'], 
            v['geocodes']['main']['longitude'],  
            no_category))

print("Completado")
# Out:
# Procesando los venues de Toronto: The Beaches
# Procesando los venues de Toronto: The Danforth West, Riverdale
# Procesando los venues de Toronto: India Bazaar, The Beaches West
# Procesando los venues de Toronto: Studio District
# Procesando los venues de Toronto: Lawrence Park
# Procesando los venues de Toronto: Davisville North
# Procesando los venues de Toronto: North Toronto West,  Lawrence Park
# Procesando los venues de Toronto: Davisville
# Procesando los venues de Toronto: Moore Park, Summerhill East
# Procesando los venues de Toronto: Summerhill West, Rathnelly, South Hill, Forest Hill SE, Deer Park
# Procesando los venues de Toronto: Rosedale
# Procesando los venues de Toronto: St. James Town, Cabbagetown
# Procesando los venues de Toronto: Church and Wellesley
# Procesando los venues de Toronto: Regent Park, Harbourfront
# Procesando los venues de Toronto: Garden District, Ryerson
# Procesando los venues de Toronto: St. James Town
# Procesando los venues de Toronto: Berczy Park
# Procesando los venues de Toronto: Central Bay Street
# Procesando los venues de Toronto: Richmond, Adelaide, King
# Procesando los venues de Toronto: Harbourfront East, Union Station, Toronto Islands
# Procesando los venues de Toronto: Toronto Dominion Centre, Design Exchange
# Procesando los venues de Toronto: Commerce Court, Victoria Hotel
# Procesando los venues de Toronto: Roselawn
# Procesando los venues de Toronto: Forest Hill North & West
# Procesando los venues de Toronto: The Annex, North Midtown, Yorkville
# Procesando los venues de Toronto: University of Toronto, Harbord
# Procesando los venues de Toronto: Kensington Market, Chinatown, Grange Park
# Procesando los venues de Toronto: CN Tower, King and Spadina, Railway Lands, Harbourfront West, Bathurst Quay, South Niagara, Island airport
# Procesando los venues de Toronto: Stn A PO Boxes
# Procesando los venues de Toronto: First Canadian Place, Underground city
# Procesando los venues de Toronto: Christie
# Procesando los venues de Toronto: Dufferin, Dovercourt Village
# Procesando los venues de Toronto: Little Portugal, Trinity
# Procesando los venues de Toronto: Brockton, Parkdale Village, Exhibition Place
# Procesando los venues de Toronto: High Park, The Junction South
# Procesando los venues de Toronto: Parkdale, Roncesvalles
# Procesando los venues de Toronto: Runnymede, Swansea
# Procesando los venues de Toronto: Queen's Park, Ontario Provincial Government
# Procesando los venues de Toronto: Business reply mail Processing Centre, South Central Letter Processing Plant Toronto
# Completado

# %%
# Convertimos la lista a un data frame
toronto_venues = pd.DataFrame(venues_list)
toronto_venues.columns = [
    'Barrio', 'Barrio Latitud', 'Barrio Longitud', 
    'Venue', 'Venue Latitude', 'Venue Longitude', 'Venue Category']

# %%
print(toronto_venues.shape)
toronto_venues.head()
# Out:
# (1950, 7)
#         Barrio  Barrio Latitud  Barrio Longitud                        Venue  \
# 0  The Beaches       43.676357       -79.293031                  Fox Theatre
# 1  The Beaches       43.676357       -79.293031  The Fill Station Sports Bar
# 2  The Beaches       43.676357       -79.293031                    Starbucks
# 3  The Beaches       43.676357       -79.293031          Woodbine Beach Park
# 4  The Beaches       43.676357       -79.293031                     The Wren
#
#    Venue Latitude  Venue Longitude       Venue Category
# 0       43.672895       -79.287358  Indie Movie Theater
# 1       43.673361       -79.284765                  Pub
# 2       43.668443       -79.307936          Coffee Shop
# 3       43.661820       -79.307921                 Park
# 4       43.682552       -79.327981                  Bar

# %% [markdown]
# Mostramos el número de venues de cada barrio

# %%
toronto_venues.groupby('Barrio').count()
# Out:
#                                                     Barrio Latitud  \
# Barrio
# Berczy Park                                                     50
# Brockton, Parkdale Village, Exhibition Place                    50
# Business reply mail Processing Centre, South Ce...              50
# CN Tower, King and Spadina, Railway Lands, Harb...              50
# Central Bay Street                                              50
# Christie                                                        50
# Church and Wellesley                                            50
# Commerce Court, Victoria Hotel                                  50
# Davisville                                                      50
# Davisville North                                                50
# Dufferin, Dovercourt Village                                    50
# First Canadian Place, Underground city                          50
# Forest Hill North & West                                        50
# Garden District, Ryerson                                        50
# Harbourfront East, Union Station, Toronto Islands               50
# High Park, The Junction South                                   50
# India Bazaar, The Beaches West                                  50
# Kensington Market, Chinatown, Grange Park                       50
# Lawrence Park                                                   50
# Little Portugal, Trinity                                        50
# Moore Park, Summerhill East                                     50
# North Toronto West,  Lawrence Park                              50
# Parkdale, Roncesvalles                                          50
# Queen's Park, Ontario Provincial Government                     50
# Regent Park, Harbourfront                                       50
# Richmond, Adelaide, King                                        50
# Rosedale                                                        50
# Roselawn                                                        50
# Runnymede, Swansea                                              50
# St. James Town                                                  50
# St. James Town, Cabbagetown                                     50
# Stn A PO Boxes                                                  50
# Studio District                                                 50
# Summerhill West, Rathnelly, South Hill, Forest ...              50
# The Annex, North Midtown, Yorkville                             50
# The Beaches                                                     50
# The Danforth West, Riverdale                                    50
# Toronto Dominion Centre, Design Exchange                        50
# University of Toronto, Harbord                                  50
#
#                                                     Barrio Longitud  Venue  \
# Barrio
# Berczy Park                                                      50     50
# Brockton, Parkdale Village, Exhibition Place                     50     50
# Business reply mail Processing Centre, South Ce...               50     50
# CN Tower, King and Spadina, Railway Lands, Harb...               50     50
# Central Bay Street                                               50     50
# Christie                                                         50     50
# Church and Wellesley                                             50     50
# Commerce Court, Victoria Hotel                                   50     50
# Davisville                                                       50     50
# Davisville North                                                 50     50
# Dufferin, Dovercourt Village                                     50     50
# First Canadian Place, Underground city                           50     50
# Forest Hill North & West                                         50     50
# Garden District, Ryerson                                         50     50
# Harbourfront East, Union Station, Toronto Islands                50     50
# High Park, The Junction South                                    50     50
# India Bazaar, The Beaches West                                   50     50
# Kensington Market, Chinatown, Grange Park                        50     50
# Lawrence Park                                                    50     50
# Little Portugal, Trinity                                         50     50
# Moore Park, Summerhill East                                      50     50
# North Toronto West,  Lawrence Park                               50     50
# Parkdale, Roncesvalles                                           50     50
# Queen's Park, Ontario Provincial Government                      50     50
# Regent Park, Harbourfront                                        50     50
# Richmond, Adelaide, King                                         50     50
# Rosedale                                                         50     50
# Roselawn                                                         50     50
# Runnymede, Swansea                                               50     50
# St. James Town                                                   50     50
# St. James Town, Cabbagetown                                      50     50
# Stn A PO Boxes                                                   50     50
# Studio District                                                  50     50
# Summerhill West, Rathnelly, South Hill, Forest ...               50     50
# The Annex, North Midtown, Yorkville                              50     50
# The Beaches                                                      50     50
# The Danforth West, Riverdale                                     50     50
# Toronto Dominion Centre, Design Exchange                         50     50
# University of Toronto, Harbord                                   50     50
#
#                                                     Venue Latitude  \
# Barrio
# Berczy Park                                                     50
# Brockton, Parkdale Village, Exhibition Place                    50
# Business reply mail Processing Centre, South Ce...              50
# CN Tower, King and Spadina, Railway Lands, Harb...              50
# Central Bay Street                                              50
# Christie                                                        50
# Church and Wellesley                                            50
# Commerce Court, Victoria Hotel                                  50
# Davisville                                                      50
# Davisville North                                                50
# Dufferin, Dovercourt Village                                    50
# First Canadian Place, Underground city                          50
# Forest Hill North & West                                        50
# Garden District, Ryerson                                        50
# Harbourfront East, Union Station, Toronto Islands               50
# High Park, The Junction South                                   50
# India Bazaar, The Beaches West                                  50
# Kensington Market, Chinatown, Grange Park                       50
# Lawrence Park                                                   50
# Little Portugal, Trinity                                        50
# Moore Park, Summerhill East                                     50
# North Toronto West,  Lawrence Park                              50
# Parkdale, Roncesvalles                                          50
# Queen's Park, Ontario Provincial Government                     50
# Regent Park, Harbourfront                                       50
# Richmond, Adelaide, King                                        50
# Rosedale                                                        50
# Roselawn                                                        50
# Runnymede, Swansea                                              50
# St. James Town                                                  50
# St. James Town, Cabbagetown                                     50
# Stn A PO Boxes                                                  50
# Studio District                                                 50
# Summerhill West, Rathnelly, South Hill, Forest ...              50
# The Annex, North Midtown, Yorkville                             50
# The Beaches                                                     50
# The Danforth West, Riverdale                                    50
# Toronto Dominion Centre, Design Exchange                        50
# University of Toronto, Harbord                                  50
#
#                                                     Venue Longitude  \
# Barrio
# Berczy Park                                                      50
# Brockton, Parkdale Village, Exhibition Place                     50
# Business reply mail Processing Centre, South Ce...               50
# CN Tower, King and Spadina, Railway Lands, Harb...               50
# Central Bay Street                                               50
# Christie                                                         50
# Church and Wellesley                                             50
# Commerce Court, Victoria Hotel                                   50
# Davisville                                                       50
# Davisville North                                                 50
# Dufferin, Dovercourt Village                                     50
# First Canadian Place, Underground city                           50
# Forest Hill North & West                                         50
# Garden District, Ryerson                                         50
# Harbourfront East, Union Station, Toronto Islands                50
# High Park, The Junction South                                    50
# India Bazaar, The Beaches West                                   50
# Kensington Market, Chinatown, Grange Park                        50
# Lawrence Park                                                    50
# Little Portugal, Trinity                                         50
# Moore Park, Summerhill East                                      50
# North Toronto West,  Lawrence Park                               50
# Parkdale, Roncesvalles                                           50
# Queen's Park, Ontario Provincial Government                      50
# Regent Park, Harbourfront                                        50
# Richmond, Adelaide, King                                         50
# Rosedale                                                         50
# Roselawn                                                         50
# Runnymede, Swansea                                               50
# St. James Town                                                   50
# St. James Town, Cabbagetown                                      50
# Stn A PO Boxes                                                   50
# Studio District                                                  50
# Summerhill West, Rathnelly, South Hill, Forest ...               50
# The Annex, North Midtown, Yorkville                              50
# The Beaches                                                      50
# The Danforth West, Riverdale                                     50
# Toronto Dominion Centre, Design Exchange                         50
# University of Toronto, Harbord                                   50
#
#                                                     Venue Category
# Barrio
# Berczy Park                                                     50
# Brockton, Parkdale Village, Exhibition Place                    50
# Business reply mail Processing Centre, South Ce...              50
# CN Tower, King and Spadina, Railway Lands, Harb...              50
# Central Bay Street                                              50
# Christie                                                        50
# Church and Wellesley                                            50
# Commerce Court, Victoria Hotel                                  50
# Davisville                                                      50
# Davisville North                                                50
# Dufferin, Dovercourt Village                                    50
# First Canadian Place, Underground city                          50
# Forest Hill North & West                                        50
# Garden District, Ryerson                                        50
# Harbourfront East, Union Station, Toronto Islands               50
# High Park, The Junction South                                   50
# India Bazaar, The Beaches West                                  50
# Kensington Market, Chinatown, Grange Park                       50
# Lawrence Park                                                   50
# Little Portugal, Trinity                                        50
# Moore Park, Summerhill East                                     50
# North Toronto West,  Lawrence Park                              50
# Parkdale, Roncesvalles                                          50
# Queen's Park, Ontario Provincial Government                     50
# Regent Park, Harbourfront                                       50
# Richmond, Adelaide, King                                        50
# Rosedale                                                        50
# Roselawn                                                        50
# Runnymede, Swansea                                              50
# St. James Town                                                  50
# St. James Town, Cabbagetown                                     50
# Stn A PO Boxes                                                  50
# Studio District                                                 50
# Summerhill West, Rathnelly, South Hill, Forest ...              50
# The Annex, North Midtown, Yorkville                             50
# The Beaches                                                     50
# The Danforth West, Riverdale                                    50
# Toronto Dominion Centre, Design Exchange                        50
# University of Toronto, Harbord                                  50

# %% [markdown]
# Se van a contar cuantos venues unicos hay en la ciudad de Toronto

# %%
print('Existen {} unicos'.format(
    len(toronto_venues['Venue Category'].unique())))
# Out:
# Existen 104 unicos

# %% [markdown]
# Ahora realizaremos un analisis por cada barrio

# %%
toronto_onehot = pd.get_dummies(toronto_venues[['Venue Category']], prefix="", prefix_sep="")
toronto_onehot.head()
# Agregamos la columna de Barrios nuevamente al DataFrame como NombreBarrio
toronto_onehot.insert(0, 'NombreBarrio', toronto_venues['Barrio']) 
toronto_onehot.head()
toronto_onehot.shape
# Out:
# (1950, 105)

# %% [markdown]
# Vamos a analizar la frecuencia de aparición de cada categoria

# %%
toronto_grouped = toronto_onehot.groupby('NombreBarrio').mean().reset_index()
toronto_grouped
# Out:
#                                          NombreBarrio  American Restaurant  \
# 0                                         Berczy Park                 0.02
# 1        Brockton, Parkdale Village, Exhibition Place                 0.00
# 2   Business reply mail Processing Centre, South C...                 0.02
# 3   CN Tower, King and Spadina, Railway Lands, Har...                 0.02
# 4                                  Central Bay Street                 0.02
# 37                             0.00                   0.00      0.02
# 38                             0.00                   0.00      0.02
#
# [39 rows x 105 columns]

# %% [markdown]
# Mostramos el listado de barrios con el top 5 de de venues disponibles

# %%
num_top_venues = 5
for neighborhood in toronto_grouped['NombreBarrio']:
    print("#####{}#####".format(neighborhood))
    temp = toronto_grouped[toronto_grouped['NombreBarrio'] == neighborhood].T.reset_index()
    temp.columns = ['venue','frecuencia']
    temp = temp.iloc[1:]
    temp['frecuencia'] = temp['frecuencia'].astype(float)
    temp = temp.round({'frecuencia': 2})
    print(temp.sort_values('frecuencia', ascending=False).reset_index(drop=True).head(num_top_venues))
    print('\n')
# Out:
# #####Berczy Park#####
#          venue  frecuencia
# 0         Café        0.08
# 1         Park        0.06
# 2  Music Venue        0.06
# 3   Restaurant        0.04
# 4  Coffee Shop        0.04
#
#
# #####Brockton, Parkdale Village, Exhibition Place#####
#           venue  frecuencia
# 0  Cocktail Bar        0.08
# 1        Bakery        0.06
# 2           Bar        0.06
# 3          Park        0.06
# 4      Pizzeria        0.06
#
#
# #####Business reply mail Processing Centre, South Central Letter Processing Plant Toronto#####
#              venue  frecuencia
# 0             Café        0.10
# 1      Coffee Shop        0.08
# 2             Park        0.06
# 3          Brewery        0.04
# 4  Farmers' Market        0.04
#
#
# #####CN Tower, King and Spadina, Railway Lands, Harbourfront West, Bathurst Quay, South Niagara, Island airport#####
#        venue  frecuencia
# 0       Park        0.10
# 1   Pizzeria        0.06
# 2     Bakery        0.06
# 3    Theater        0.04
# 4  Bookstore        0.04
#
#
# #####Central Bay Street#####
#                          venue  frecuencia
# 0                         Café        0.08
# 1                  Music Venue        0.06
# 2               Clothing Store        0.06
# 3  Grocery Store / Supermarket        0.04
# 4                   Hair Salon        0.04
#
#
# #####Christie#####
#                          venue  frecuencia
# 0                       Bakery        0.08
# 1                         Café        0.06
# 2                 Cocktail Bar        0.06
# 3                  Coffee Shop        0.06
# 4  Grocery Store / Supermarket        0.04
#
#
# #####Church and Wellesley#####
#             venue  frecuencia
# 0            Café        0.12
# 1  Clothing Store        0.06
# 2          Bakery        0.04
# 3       Juice Bar        0.04
# 4     Music Venue        0.04
#
#
# #####Commerce Court, Victoria Hotel#####
#             venue  frecuencia
# 0            Café        0.08
# 1     Music Venue        0.06
# 2            Park        0.06
# 3  Clothing Store        0.04
# 4         Theater        0.04
#
#
# #####Davisville#####
#             venue  frecuencia
# 0            Park        0.08
# 1             Bar        0.06
# 2            Café        0.06
# 3  Clothing Store        0.06
# 4      Barbershop        0.04
#
#
# #####Davisville North#####
#                          venue  frecuencia
# 0                         Park        0.08
# 1                          Bar        0.06
# 2                         Café        0.06
# 3  Grocery Store / Supermarket        0.04
# 4          Japanese Restaurant        0.04
#
#
# #####Dufferin, Dovercourt Village#####
#                 venue  frecuencia
# 0              Bakery        0.10
# 1                 Bar        0.08
# 2            Pizzeria        0.06
# 3  Italian Restaurant        0.06
# 4                Café        0.06
#
#
# #####First Canadian Place, Underground city#####
#             venue  frecuencia
# 0            Café        0.08
# 1     Music Venue        0.06
# 2            Park        0.06
# 3         Theater        0.04
# 4  Clothing Store        0.04
#
#
# #####Forest Hill North & West#####
#                          venue  frecuencia
# 0                       Bakery        0.08
# 1  Grocery Store / Supermarket        0.06
# 2                         Park        0.04
# 3              Farmers' Market        0.04
# 4                  Music Venue        0.04
#
#
# #####Garden District, Ryerson#####
#          venue  frecuencia
# 0         Café        0.10
# 1  Music Venue        0.06
# 2  Coffee Shop        0.06
# 3         Park        0.04
# 4     Pizzeria        0.04
#
#
# #####Harbourfront East, Union Station, Toronto Islands#####
#                  venue  frecuencia
# 0                 Café        0.08
# 1                 Park        0.06
# 2          Music Venue        0.06
# 3  American Restaurant        0.04
# 4              Theater        0.04
#
#
# #####High Park, The Junction South#####
#                 venue  frecuencia
# 0              Bakery        0.10
# 1                Café        0.06
# 2  Italian Restaurant        0.06
# 3         Coffee Shop        0.06
# 4                 Bar        0.06
#
#
# #####India Bazaar, The Beaches West#####
#                          venue  frecuencia
# 0                         Café        0.10
# 1                  Coffee Shop        0.08
# 2                         Park        0.06
# 3     Furniture and Home Store        0.04
# 4  Grocery Store / Supermarket        0.04
#
#
# #####Kensington Market, Chinatown, Grange Park#####
#           venue  frecuencia
# 0        Bakery        0.08
# 1      Pizzeria        0.08
# 2      Wine Bar        0.04
# 3  Cocktail Bar        0.04
# 4   Art Gallery        0.04
#
#
# #####Lawrence Park#####
#                    venue  frecuencia
# 0                   Park        0.08
# 1                    Bar        0.06
# 2                   Café        0.06
# 3     Italian Restaurant        0.04
# 4  Sporting Goods Retail        0.04
#
#
# #####Little Portugal, Trinity#####
#           venue  frecuencia
# 0  Cocktail Bar        0.08
# 1      Pizzeria        0.06
# 2           Bar        0.06
# 3        Bakery        0.06
# 4          Café        0.04
#
#
# #####Moore Park, Summerhill East#####
#                          venue  frecuencia
# 0                         Café        0.10
# 1                         Park        0.08
# 2  Grocery Store / Supermarket        0.06
# 3               Clothing Store        0.06
# 4                       Bakery        0.04
#
#
# #####North Toronto West,  Lawrence Park#####
#                    venue  frecuencia
# 0                   Park        0.08
# 1                 Bakery        0.06
# 2                    Bar        0.06
# 3                   Café        0.04
# 4  Sporting Goods Retail        0.04
#
#
# #####Parkdale, Roncesvalles#####
#                 venue  frecuencia
# 0              Bakery        0.08
# 1                 Bar        0.08
# 2            Wine Bar        0.06
# 3  Italian Restaurant        0.06
# 4         Coffee Shop        0.06
#
#
# #####Queen's Park, Ontario Provincial Government#####
#                          venue  frecuencia
# 0                  Music Venue        0.06
# 1               Clothing Store        0.06
# 2                         Café        0.06
# 3  Grocery Store / Supermarket        0.04
# 4                       Bakery        0.04
#
#
# #####Regent Park, Harbourfront#####
#          venue  frecuencia
# 0         Café        0.10
# 1         Park        0.08
# 2  Coffee Shop        0.08
# 3   Restaurant        0.06
# 4       Bistro        0.04
#
#
# #####Richmond, Adelaide, King#####
#                  venue  frecuencia
# 0                 Café        0.08
# 1  American Restaurant        0.04
# 2                  Spa        0.04
# 3           Hair Salon        0.04
# 4       Clothing Store        0.04
#
#
# #####Rosedale#####
#                          venue  frecuencia
# 0                         Café        0.14
# 1               Clothing Store        0.06
# 2  Grocery Store / Supermarket        0.04
# 3                  Music Venue        0.04
# 4                        Diner        0.04
#
#
# #####Roselawn#####
#                 venue  frecuencia
# 0              Bakery        0.10
# 1                Park        0.06
# 2                Café        0.04
# 3  Italian Restaurant        0.04
# 4         Music Venue        0.04
#
#
# #####Runnymede, Swansea#####
#                 venue  frecuencia
# 0              Bakery        0.10
# 1                 Bar        0.08
# 2         Coffee Shop        0.06
# 3  Italian Restaurant        0.06
# 4                Café        0.06
#
#
# #####St. James Town#####
#             venue  frecuencia
# 0            Café        0.08
# 1     Coffee Shop        0.06
# 2      Restaurant        0.06
# 3            Park        0.06
# 4  Clothing Store        0.04
#
#
# #####St. James Town, Cabbagetown#####
#          venue  frecuencia
# 0         Café        0.10
# 1  Coffee Shop        0.08
# 2         Park        0.06
# 3   Restaurant        0.06
# 4    Juice Bar        0.04
#
#
# #####Stn A PO Boxes#####
#          venue  frecuencia
# 0         Café        0.08
# 1         Park        0.06
# 2  Music Venue        0.06
# 3  Coffee Shop        0.06
# 4   Restaurant        0.04
#
#
# #####Studio District#####
#          venue  frecuencia
# 0         Café        0.10
# 1  Coffee Shop        0.08
# 2         Park        0.06
# 3          Bar        0.04
# 4        Diner        0.04
#
#
# #####Summerhill West, Rathnelly, South Hill, Forest Hill SE, Deer Park#####
#                          venue  frecuencia
# 0                         Café        0.08
# 1                       Bakery        0.06
# 2  Grocery Store / Supermarket        0.06
# 3                     Wine Bar        0.04
# 4              Farmers' Market        0.04
#
#
# #####The Annex, North Midtown, Yorkville#####
#                          venue  frecuencia
# 0                 Cocktail Bar        0.06
# 1                         Café        0.06
# 2                       Bakery        0.06
# 3  Grocery Store / Supermarket        0.06
# 4           Italian Restaurant        0.04
#
#
# #####The Beaches#####
#          venue  frecuencia
# 0         Café        0.08
# 1  Coffee Shop        0.08
# 2         Park        0.08
# 3   Restaurant        0.04
# 4        Diner        0.04
#
#
# #####The Danforth West, Riverdale#####
#                       venue  frecuencia
# 0                      Café        0.08
# 1               Coffee Shop        0.08
# 2  Furniture and Home Store        0.04
# 3            Clothing Store        0.04
# 4           Farmers' Market        0.04
#
#
# #####Toronto Dominion Centre, Design Exchange#####
#          venue  frecuencia
# 0         Café        0.08
# 1         Park        0.06
# 2  Music Venue        0.06
# 3      Theater        0.04
# 4   Hair Salon        0.04
#
#
# #####University of Toronto, Harbord#####
#                          venue  frecuencia
# 0  Grocery Store / Supermarket        0.06
# 1                     Pizzeria        0.06
# 2               Clothing Store        0.04
# 3                       Bakery        0.04
# 4                         Café        0.04

# %% [markdown]
# Vamos a crear un nuevo dataframe con el top 10 de venues mas comunes

# %% [markdown]
# Ordenamos por orden de frecuencia

# %%
def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    
    return row_categories_sorted.index.values[0:num_top_venues]

# %% [markdown]
# Ahora creamos el data frame

# %%
num_top_venues = 10

indicators = ['st', 'nd', 'rd']

# create columns according to number of top venues
# creamos la columnas dependiendo del numero de top venues
columns = ['Barrio']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Venue mas comun'.format(ind+1, indicators[ind]))
    except:
        columns.append('{} Venue mas comun'.format(ind+1))

# creacion del nuevo data frame
neighborhoods_venues_sorted = pd.DataFrame(columns=columns)
neighborhoods_venues_sorted['Barrio'] = toronto_grouped['NombreBarrio']

for ind in np.arange(toronto_grouped.shape[0]):
    neighborhoods_venues_sorted.iloc[ind, 1:] = return_most_common_venues(
        toronto_grouped.iloc[ind, :], num_top_venues)

neighborhoods_venues_sorted
# Out:
#
# 10                      Park            Korean Restaurant
# 11                  Pizzeria                       Museum
# 12               Coffee Shop                         Café
# 13            Clothing Store                  Music Store
# 14                Hair Salon                     Pizzeria
# 15              Cocktail Bar                         Park
# 16           Farmers' Market                      Brewery
# 17                Night Club  Grocery Store / Supermarket
# 18                Barbershop  Grocery Store / Supermarket
# 19                  Wine Bar            Korean Restaurant
# 20               Music Venue                        Diner
# 21            Clothing Store                   Barbershop
# 22              Cocktail Bar                         Café
# 23             Movie Theater                   Hair Salon
# 24  Furniture and Home Store               Clothing Store
# 25                  Pizzeria                         Park
# 26                      Park                  Coffee Shop
# 27                Barbershop              Farmers' Market
# 28              Cocktail Bar                     Wine Bar
# 29                       Bar                  Music Venue
# 30                     Diner              Farmers' Market
# 31            Clothing Store                      Theater
# 32  Furniture and Home Store                       Bistro
# 33                Barbershop           Italian Restaurant
# 34               Art Gallery                         Park
# 35                       Bar              Farmers' Market
# 36                   Brewery                          Bar
# 37                  Pizzeria          American Restaurant
# 38                      Park                 Cocktail Bar
#
#               9 Venue mas comun           10 Venue mas comun
# 0                        Museum                     Pizzeria
# 1                          Café           Italian Restaurant
# 2   Grocery Store / Supermarket                        Diner
# 3                   Optometrist                   Night Club
# 4           Japanese Restaurant                Jewelry Store
# 5                  Record Store             Ramen Restaurant
# 6                  Dessert Shop                       Retail
# 7                  Concert Hall                 Dance Studio
# 8   Grocery Store / Supermarket                  Music Store
# 9            Italian Restaurant     Furniture and Home Store
# 10              Farmers' Market                Movie Theater
# 11              Farmers' Market     Furniture and Home Store
# 12                   Barbershop             Ramen Restaurant
# 13              Farmers' Market                   Shoe Store
# 14                       Museum                    Drugstore
# 15                     Pizzeria              Farmers' Market
# 16                   Restaurant                          Bar
# 17                   Hair Salon     Home Improvement Service
# 18                  Event Space              Farmers' Market
# 19          Japanese Restaurant    Fashion Accessories Store
# 20                 Dessert Shop                          Spa
# 21  Grocery Store / Supermarket                       Retail
# 22            Korean Restaurant            French Restaurant
# 23                  Art Gallery          Japanese Restaurant
# 24                   Playground                       Retail
# 25                          Bar                   Shoe Store
# 26                    Juice Bar                       Bakery
# 27                  Coffee Shop               Clothing Store
# 28            Korean Restaurant                  Art Gallery
# 29                       Bistro     Furniture and Home Store
# 30               Clothing Store     Furniture and Home Store
# 31                       Museum                     Pizzeria
# 32               Clothing Store  Grocery Store / Supermarket
# 33                         Park                  Music Venue
# 34                  Music Store                Jewelry Store
# 35  Grocery Store / Supermarket                      Brewery
# 36                   Restaurant                        Diner
# 37                       Museum     Furniture and Home Store
# 38         Fast Food Restaurant                  Coffee Shop

# %% [markdown]
# ### Cluster de Barrios de Toronto

# %% [markdown]
# Vamos a usar K-means y hacer 5 clusters de barrios

# %%
# Set number of clusters
k = 5

# Drop the neighborhood name column so that each column contains only the feature set.
toronto_grouped_clustering = toronto_grouped.drop('NombreBarrio', 1)

# Run k-means clustering
kmeans = KMeans(n_clusters=k, random_state=0).fit(toronto_grouped_clustering)

# Check cluster labels generated for each row in the dataframe
kmeans.labels_[0:10]
# Out:
# /var/folders/79/4l20n_4n3dn2twlpxr55cbg80000gn/T/ipykernel_94031/557006112.py:5: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   toronto_grouped_clustering = toronto_grouped.drop('NombreBarrio', 1)
# array([0, 1, 2, 0, 3, 1, 3, 0, 4, 4], dtype=int32)

# %% [markdown]
# Vamos a crear el nuevo dataframe con la informacion de los barrios y el top 10 de los venues

# %%
# Add clustering labels
neighborhoods_venues_sorted.insert(0, 'Cluster Labels', kmeans.labels_)

toronto_merged = toronto_data

# Merge toronto_grouped with toronto_data to add latitude/longitude for each neighborhood
toronto_merged = toronto_merged.join(neighborhoods_venues_sorted.set_index('Barrio'), on='Barrio')

print(toronto_merged.shape)
toronto_merged.head()
# Out:
# (39, 16)
#   Codigo_Postal           Ciudad                          Barrio   Latitude  \
# 0           M4E     East Toronto                     The Beaches  43.676357
# 1           M4K     East Toronto    The Danforth West, Riverdale  43.679557
# 2           M4L     East Toronto  India Bazaar, The Beaches West  43.668999
# 3           M4M     East Toronto                 Studio District  43.659526
# 4           M4N  Central Toronto                   Lawrence Park  43.728020
#
#    Longitude  Cluster Labels 1st Venue mas comun 2nd Venue mas comun  \
# 0 -79.293031               2                Café         Coffee Shop
# 1 -79.352188               2                Café         Coffee Shop
# 2 -79.315572               2                Café         Coffee Shop
# 3 -79.340923               2                Café         Coffee Shop
# 4 -79.388790               4                Park                 Bar
#
#         3rd Venue mas comun         4 Venue mas comun  \
# 0                      Park                Restaurant
# 1  Furniture and Home Store            Clothing Store
# 2                      Park  Furniture and Home Store
# 3                      Park                       Bar
# 4                      Café        Italian Restaurant
#
#              5 Venue mas comun    6 Venue mas comun         7 Venue mas comun  \
# 0                        Diner  Japanese Restaurant                       Bar
# 1              Farmers' Market          Music Venue                   Brewery
# 2  Grocery Store / Supermarket                Diner           Farmers' Market
# 3                        Diner           Restaurant  Furniture and Home Store
# 4        Sporting Goods Retail               Bakery                Barbershop
#
#              8 Venue mas comun            9 Venue mas comun  \
# 0              Farmers' Market  Grocery Store / Supermarket
# 1                          Bar                   Restaurant
# 2                      Brewery                   Restaurant
# 3                       Bistro               Clothing Store
# 4  Grocery Store / Supermarket                  Event Space
#
#             10 Venue mas comun
# 0                      Brewery
# 1                        Diner
# 2                          Bar
# 3  Grocery Store / Supermarket
# 4              Farmers' Market

# %% [markdown]
# Visualizacion de los clusters

# %%
# Create a map instance
mapa_toronto = folium.Map(
    location=[coordenadas.latitude, coordenadas.longitude],
    zoom_start=11)

# Set color scheme for the clusters
x = np.arange(k)
ys = [i + x + (i*x)**2 for i in range(k)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# Add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(
        toronto_merged['Latitude'], toronto_merged['Longitude'],
        toronto_merged['Barrio'], toronto_merged['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(mapa_toronto)
       
mapa_toronto
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_882a3b652f211c6c55ba97d2d4c2543a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_882a3b652f211c6c55ba97d2d4c2543a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_882a3b652f211c6c55ba97d2d4c2543a = L.map(
#                 &quot;map_882a3b652f211c6c55ba97d2d4c2543a&quot;,
#                 {
#                     center: [43.6534817, -79.3839347],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_085e82d38dbf41e460d4e9ecf95f1466 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_882a3b652f211c6c55ba97d2d4c2543a);
#
#
#             var circle_marker_0e2b499e99159deea1546a9b8c3f77ac = L.circleMarker(
#                 [43.6763574, -79.2930312],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#00b5eb&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#00b5eb&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_882a3b652f211c6c55ba97d2d4c2543a);
#
#
#         var popup_535ab2e77b79a4907ed36c25fc82c5d6 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_2b342ead1e879ffc13f3271ef31c0f49 = $(`&lt;div id=&quot;html_2b342ead1e879ffc13f3271ef31c0f49&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;The Beaches Cluster 2&lt;/div&gt;`)[0];
#                 popup_535ab2e77b79a4907ed36c25fc82c5d6.setContent(html_2b342ead1e879ffc13f3271ef31c0f49);
#
#
#
#         circle_marker_0e2b499e99159deea1546a9b8c3f77ac.bindPopup(popup_535ab2e77b79a4907ed36c25fc82c5d6)
#         ;
#
#
#
#
#             var circle_marker_acf6956e8a53f0c1ef8bdc1612353d9d = L.circleMarker(
#                 [43.6795571, -79.352188],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#00b5eb&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#00b5eb&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_882a3b652f211c6c55ba97d2d4c2543a);
#
#
#         var popup_6fb27cee683e4bef4e4d747f82e833f4 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_be6ff90edf811731cb9b62d0825915bd = $(`&lt;div id=&quot;html_be6ff90edf811731cb9b62d0825915bd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;The Danforth West, Riverdale Cluster 2&lt;/div&gt;`)[0];
#                 popup_6fb27cee683e4bef4e4d747f82e833f4.setContent(html_be6ff90edf811731cb9b62d0825915bd);
#
#
#
#         circle_marker_acf6956e8a53f0c1ef8bdc1612353d9d.bindPopup(popup_6fb27cee683e4bef4e4d747f82e833f4)
#         ;
#
#
#
#
#             var circle_marker_dd88a71c167f9626b9b9b4694f8c867f = L.circleMarker(
#                 [43.6689985, -79.3155716],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#00b5eb&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#00b5eb&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_882a3b652f211c6c55ba97d2d4c2543a);
#
#
#         var popup_95685ba41f775aec3d345bd2aef7a661 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ac3fe5b65d024360402c04a635861185 = $(`&lt;div id=&quot;html_ac3fe5b65d024360402c04a635861185&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;India Bazaar, The Beaches West Cluster 2&lt;/div&gt;`)[0];
#                 popup_95685ba41f775aec3d345bd2aef7a661.setContent(html_ac3fe5b65d024360402c04a635861185);
#
#
#
#         circle_marker_dd88a71c167f9626b9b9b4694f8c867f.bindPopup(popup_95685ba41f775aec3d345bd2aef7a661)
#         ;
#
#
#
#
#             var circle_marker_ba50150037dd5d40f337c1886d704d42 = L.circleMarker(
#                 [43.6595255, -79.340923],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#00b5eb&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;

# %% [markdown]
# ### Analisis de los clusters

# %% [markdown]
# ##### Cluster 0

# %%
cluster_0 = toronto_merged.loc[toronto_merged['Cluster Labels'] == 0,
                               toronto_merged.columns[
                                   [2] + list(range(
                                       5, toronto_merged.shape[1]))]]
cluster_0
# Out:
#                                                Barrio  Cluster Labels  \
# 14                           Garden District, Ryerson               0
# 15                                     St. James Town               0
# 16                                        Berczy Park               0
# 18                           Richmond, Adelaide, King               0
# 19  Harbourfront East, Union Station, Toronto Islands               0
# 20           Toronto Dominion Centre, Design Exchange               0
# 21                     Commerce Court, Victoria Hotel               0
# 27  CN Tower, King and Spadina, Railway Lands, Har...               0
# 28                                     Stn A PO Boxes               0
# 29             First Canadian Place, Underground city               0
#
#    1st Venue mas comun  2nd Venue mas comun 3rd Venue mas comun  \
# 14                Café          Music Venue         Coffee Shop
# 15                Café          Coffee Shop          Restaurant
# 16                Café                 Park         Music Venue
# 18                Café  American Restaurant                 Spa
# 19                Café                 Park         Music Venue
# 20                Café                 Park         Music Venue
# 21                Café          Music Venue                Park
# 27                Park             Pizzeria              Bakery
# 28                Café                 Park         Music Venue
# 29                Café          Music Venue                Park
#
# 37                     Pizzeria     Movie Theater
#
#               8 Venue mas comun     9 Venue mas comun  \
# 12                  Coffee Shop          Dessert Shop
# 17                  Art Gallery   Japanese Restaurant
# 24                         Park           Music Store
# 25                 Cocktail Bar  Fast Food Restaurant
# 26  Grocery Store / Supermarket            Hair Salon
# 37                   Hair Salon           Art Gallery
#
#           10 Venue mas comun
# 12                    Retail
# 17             Jewelry Store
# 24             Jewelry Store
# 25               Coffee Shop
# 26  Home Improvement Service
# 37       Japanese Restaurant

# %% [markdown]
# ##### Cluster 4

# %%
toronto_merged.loc[toronto_merged['Cluster Labels'] == 4,
                   toronto_merged.columns[
                       [2] + list(range(5, toronto_merged.shape[1]))]]
# Out:
#                                                Barrio  Cluster Labels  \
# 4                                       Lawrence Park               4
# 5                                    Davisville North               4
# 6                  North Toronto West,  Lawrence Park               4
# 7                                          Davisville               4
# 8                         Moore Park, Summerhill East               4
# 9   Summerhill West, Rathnelly, South Hill, Forest...               4
# 22                                           Roselawn               4
# 23                           Forest Hill North & West               4
#
#    1st Venue mas comun          2nd Venue mas comun  \
# 4                 Park                          Bar
# 5                 Park                          Bar
# 6                 Park                       Bakery
# 7                 Park                          Bar
# 8                 Café                         Park
# 9                 Café                       Bakery
# 22              Bakery                         Park
# 23              Bakery  Grocery Store / Supermarket
#
#             3rd Venue mas comun            4 Venue mas comun  \
# 4                          Café           Italian Restaurant
# 5                          Café  Grocery Store / Supermarket
# 6                           Bar                         Café
# 7                          Café               Clothing Store
# 8   Grocery Store / Supermarket               Clothing Store
# 9   Grocery Store / Supermarket                     Wine Bar
# 22                         Café           Italian Restaurant
# 23                         Park              Farmers' Market
#
#         5 Venue mas comun      6 Venue mas comun      7 Venue mas comun  \
# 4   Sporting Goods Retail                 Bakery             Barbershop
# 5     Japanese Restaurant                 Bakery  Sporting Goods Retail
# 6   Sporting Goods Retail     Italian Restaurant         Clothing Store
# 7              Barbershop  Sporting Goods Retail    Japanese Restaurant
# 8                  Bakery              Juice Bar            Music Venue
# 9         Farmers' Market                    Bar             Barbershop
# 22            Music Venue                    Bar             Barbershop
# 23            Music Venue     Italian Restaurant            Coffee Shop
#
#               8 Venue mas comun            9 Venue mas comun  \
# 4   Grocery Store / Supermarket                  Event Space
# 5                    Barbershop           Italian Restaurant
# 6                    Barbershop  Grocery Store / Supermarket
# 7            Italian Restaurant  Grocery Store / Supermarket
# 8                         Diner                 Dessert Shop
# 9            Italian Restaurant                         Park
# 22              Farmers' Market                  Coffee Shop
# 23                         Café                   Barbershop
#
#           10 Venue mas comun
# 4            Farmers' Market
# 5   Furniture and Home Store
# 6                     Retail
# 7                Music Store
# 8                        Spa
# 9                Music Venue
# 22            Clothing Store
# 23          Ramen Restaurant

# %% [markdown]
# ### Conclusiones
#
# - El cluster con mas barrios es el cluster 0 con 10 barrios. La categoría que aparece de forma mas común son las cafeterías que se ven en gran cantidad en lo que es Toronto al parecer
# - Los otros clusters son mas pequeños aunque no parecen diferir en gran medida unos de otros. En todos podemos ver cafeterías, parques y pastelerías en gran cantidad
# - El cluster 3 parece ser el que ofrece diferentes actividades de diferentes categorias principales
